# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv", parse_dates=['Date'],
                 encoding="ISO-8859-1",
                 dtype={"RegionName": str,
                        "RegionCode": str},
                 error_bad_lines=False)
pred = pd.read_csv("predictions.csv", 
                   parse_dates=['Date'],
                   encoding="ISO-8859-1",
                   dtype={"RegionName": str,
                          "RegionCode": str},
                   error_bad_lines=False)

# %%
df
# Out:
#       CountryName RegionName       Date  PredictedDailyNewCases  Unnamed: 0  \
# 0           Aruba        NaN 2020-01-01               59.435110         NaN
# 1           Aruba        NaN 2020-01-02               76.294088         NaN
# 2           Aruba        NaN 2020-01-03               82.705463         NaN
# 3           Aruba        NaN 2020-01-04               87.574387         NaN
# 4           Aruba        NaN 2020-01-05               87.930059         NaN
# ...           ...        ...        ...                     ...         ...
# 79375    Zimbabwe        NaN 2020-11-15                     NaN     79375.0
# 79376    Zimbabwe        NaN 2020-11-16                     NaN     79376.0
# 79377    Zimbabwe        NaN 2020-11-17                     NaN     79377.0
# 79378    Zimbabwe        NaN 2020-11-18                     NaN     79378.0
# 79379    Zimbabwe        NaN 2020-11-19                     NaN     79379.0
#
#       CountryCode RegionCode  C1_School closing  C1_Flag  \
# 0             NaN        NaN                NaN      NaN
# 1             NaN        NaN                NaN      NaN
# 2             NaN        NaN                NaN      NaN
# 3             NaN        NaN                NaN      NaN
# 4             NaN        NaN                NaN      NaN
# ...           ...        ...                ...      ...
# 79375         ZWE        NaN                1.0      1.0
# 79376         ZWE        NaN                1.0      1.0
# 79377         ZWE        NaN                NaN      NaN
# 79378         ZWE        NaN                NaN      NaN
# 79379         ZWE        NaN                NaN      NaN
#
#        C2_Workplace closing  ...  StringencyIndex  StringencyIndexForDisplay  \
# 0                       NaN  ...              NaN                        NaN
# 1                       NaN  ...              NaN                        NaN
# 2                       NaN  ...              NaN                        NaN
# 3                       NaN  ...              NaN                        NaN
# 4                       NaN  ...              NaN                        NaN
# ...                     ...  ...              ...                        ...
# 79375                   1.0  ...            67.59                      67.59
# 79376                   1.0  ...            67.59                      67.59
# 79377                   NaN  ...              NaN                      67.59
# 79378                   NaN  ...              NaN                      67.59
# 79379                   NaN  ...              NaN                      67.59
#
#        StringencyLegacyIndex  StringencyLegacyIndexForDisplay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
# ...                      ...                              ...
# 79375                  73.81                            73.81
# 79376                  73.81                            73.81
# 79377                    NaN                            73.81
# 79378                    NaN                            73.81
# 79379                    NaN                            73.81
#
#        GovernmentResponseIndex  GovernmentResponseIndexForDisplay  \
# 0                          NaN                                NaN
# 1                          NaN                                NaN
# 2                          NaN                                NaN
# 3                          NaN                                NaN
# 4                          NaN                                NaN
# ...                        ...                                ...
# 79375                    58.33                              58.33
# 79376                    58.33                              58.33
# 79377                      NaN                              58.33
# 79378                      NaN                              58.33
# 79379                      NaN                              58.33
#
#        ContainmentHealthIndex  ContainmentHealthIndexForDisplay  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
# ...                       ...                               ...
# 79375                   63.89                             63.89
# 79376                   63.89                             63.89
# 79377                     NaN                             63.89
# 79378                     NaN                             63.89
# 79379                     NaN                             63.89
#
#        EconomicSupportIndex  EconomicSupportIndexForDisplay
# 0                       NaN                             NaN
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
# ...                     ...                             ...
# 79375                  25.0                            25.0
# 79376                  25.0                            25.0
# 79377                   NaN                            25.0
# 79378                   NaN                            25.0
# 79379                   NaN                            25.0
#
# [212544 rows x 48 columns]

# %%
df
# Out:
#       CountryName RegionName       Date  PredictedDailyNewCases  Unnamed: 0  \
# 0           Aruba        NaN 2020-01-01               59.435110         NaN
# 1           Aruba        NaN 2020-01-02               76.294088         NaN
# 2           Aruba        NaN 2020-01-03               82.705463         NaN
# 3           Aruba        NaN 2020-01-04               87.574387         NaN
# 4           Aruba        NaN 2020-01-05               87.930059         NaN
# ...           ...        ...        ...                     ...         ...
# 79375    Zimbabwe        NaN 2020-11-15                     NaN     79375.0
# 79376    Zimbabwe        NaN 2020-11-16                     NaN     79376.0
# 79377    Zimbabwe        NaN 2020-11-17                     NaN     79377.0
# 79378    Zimbabwe        NaN 2020-11-18                     NaN     79378.0
# 79379    Zimbabwe        NaN 2020-11-19                     NaN     79379.0
#
#       CountryCode RegionCode  C1_School closing  C1_Flag  \
# 0             NaN        NaN                NaN      NaN
# 1             NaN        NaN                NaN      NaN
# 2             NaN        NaN                NaN      NaN
# 3             NaN        NaN                NaN      NaN
# 4             NaN        NaN                NaN      NaN
# ...           ...        ...                ...      ...
# 79375         ZWE        NaN                1.0      1.0
# 79376         ZWE        NaN                1.0      1.0
# 79377         ZWE        NaN                NaN      NaN
# 79378         ZWE        NaN                NaN      NaN
# 79379         ZWE        NaN                NaN      NaN
#
#        C2_Workplace closing  ...  StringencyIndex  StringencyIndexForDisplay  \
# 0                       NaN  ...              NaN                        NaN
# 1                       NaN  ...              NaN                        NaN
# 2                       NaN  ...              NaN                        NaN
# 3                       NaN  ...              NaN                        NaN
# 4                       NaN  ...              NaN                        NaN
# ...                     ...  ...              ...                        ...
# 79375                   1.0  ...            67.59                      67.59
# 79376                   1.0  ...            67.59                      67.59
# 79377                   NaN  ...              NaN                      67.59
# 79378                   NaN  ...              NaN                      67.59
# 79379                   NaN  ...              NaN                      67.59
#
#        StringencyLegacyIndex  StringencyLegacyIndexForDisplay  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        NaN                              NaN
# 3                        NaN                              NaN
# 4                        NaN                              NaN
# ...                      ...                              ...
# 79375                  73.81                            73.81
# 79376                  73.81                            73.81
# 79377                    NaN                            73.81
# 79378                    NaN                            73.81
# 79379                    NaN                            73.81
#
#        GovernmentResponseIndex  GovernmentResponseIndexForDisplay  \
# 0                          NaN                                NaN
# 1                          NaN                                NaN
# 2                          NaN                                NaN
# 3                          NaN                                NaN
# 4                          NaN                                NaN
# ...                        ...                                ...
# 79375                    58.33                              58.33
# 79376                    58.33                              58.33
# 79377                      NaN                              58.33
# 79378                      NaN                              58.33
# 79379                      NaN                              58.33
#
#        ContainmentHealthIndex  ContainmentHealthIndexForDisplay  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
# ...                       ...                               ...
# 79375                   63.89                             63.89
# 79376                   63.89                             63.89
# 79377                     NaN                             63.89
# 79378                     NaN                             63.89
# 79379                     NaN                             63.89
#
#        EconomicSupportIndex  EconomicSupportIndexForDisplay
# 0                       NaN                             NaN
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
# ...                     ...                             ...
# 79375                  25.0                            25.0
# 79376                  25.0                            25.0
# 79377                   NaN                            25.0
# 79378                   NaN                            25.0
# 79379                   NaN                            25.0
#
# [145962 rows x 48 columns]
