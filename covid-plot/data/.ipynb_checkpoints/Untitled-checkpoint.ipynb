# %%
import pandas as pd
import numpy as np
import pylab as plt

# %%
df = pd.read_csv("data.csv", parse_dates=['Date'],
			 encoding="ISO-8859-1",
			 dtype={"RegionName": str,
			        "RegionCode": str},
			 error_bad_lines=False)
pred = pd.read_csv("predictions.csv", parse_dates=['Date'],
			 encoding="ISO-8859-1",
			 dtype={"RegionName": str,
			        "RegionCode": str},
			 error_bad_lines=False))

# %%
df
# Out:
#        Unnamed: 0 CountryName CountryCode RegionName RegionCode       Date  \
# 0               0       Aruba         ABW        NaN        NaN 2020-01-01
# 1               1       Aruba         ABW        NaN        NaN 2020-01-02
# 2               2       Aruba         ABW        NaN        NaN 2020-01-03
# 3               3       Aruba         ABW        NaN        NaN 2020-01-04
# 4               4       Aruba         ABW        NaN        NaN 2020-01-05
# ...           ...         ...         ...        ...        ...        ...
# 79375       79375    Zimbabwe         ZWE        NaN        NaN 2020-11-15
# 79376       79376    Zimbabwe         ZWE        NaN        NaN 2020-11-16
# 79377       79377    Zimbabwe         ZWE        NaN        NaN 2020-11-17
# 79378       79378    Zimbabwe         ZWE        NaN        NaN 2020-11-18
# 79379       79379    Zimbabwe         ZWE        NaN        NaN 2020-11-19
#
# ...

# %%
pred
# Out:
#    CountryName  RegionName        Date  PredictedDailyNewCases
# 0        India         NaN  2021-01-01            39206.726721
# 1        India         NaN  2021-01-02            40074.392801
# 2        India         NaN  2021-01-03            37283.227754
# 3        India         NaN  2021-01-04            27286.932844
# 4        India         NaN  2021-01-05            26307.500986
# ..         ...         ...         ...                     ...
# 57      Mexico         NaN  2021-01-27              665.456354
# 58      Mexico         NaN  2021-01-28             5861.357197
# 59      Mexico         NaN  2021-01-29             3987.442635
# 60      Mexico         NaN  2021-01-30             4061.119631
# 61      Mexico         NaN  2021-01-31             4491.328723
#
# [62 rows x 4 columns]

# %%
df.join(pred, on="Date")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-57b2103afc1b> in <module>
# ----> 1 df.join(pred, on="Date")
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         5  K5  A5  NaN
#    7869         """
# -> 7870         return self._join_compat(
#    7871             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7872         )
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7884
#    7885         if isinstance(other, DataFrame):
# -> 7886             return merge(
#    7887                 self,
#    7888                 other,
#
# ...
